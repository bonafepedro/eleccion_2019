# %%
import requests 
from bs4 import BeautifulSoup as bs
import itertools
import string
import pandas as pd
import tribunal_electoral_scrape as tesc

# %%
lista = tesc.get_data()
# Out:
# C:\Users\usuario\Laburo\eleccion2019\tribunal_electoral_scrape.py:60: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 60 of the file C:\Users\usuario\Laburo\eleccion2019\tribunal_electoral_scrape.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   return [i.text for i in bs(response.text).select('tr td') if i.text != '']

# %%
len(lista)
# Out:
# 714

# %%
df = tesc.data_parser_1(lista)

# %%
df
# Out:
#                                     titulo  \
# 0     TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 1     TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 2     TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 3     TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 4     TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# ...                                    ...
# 9383  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 9384  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 9385  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 9386  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 9387  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
#
#                                         eleccion  \
# 0     Elecciones Provinciales 12 de Mayo de 2019
# 1     Elecciones Provinciales 12 de Mayo de 2019
# 2     Elecciones Provinciales 12 de Mayo de 2019
# 3     Elecciones Provinciales 12 de Mayo de 2019
# 4     Elecciones Provinciales 12 de Mayo de 2019
# ...                                          ...
# 9383  Elecciones Provinciales 12 de Mayo de 2019
# ...

# %%
df2 = tesc.data_parser_2(lista)

# %%
df2
# Out:
#                                    titulo  \
# 0    TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 1    TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 2    TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 3    TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 4    TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# ..                                    ...
# 708  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 709  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 710  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 711  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 712  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
#
#                                        eleccion  \
# 0    Elecciones Provinciales 12 de Mayo de 2019
# 1    Elecciones Provinciales 12 de Mayo de 2019
# 2    Elecciones Provinciales 12 de Mayo de 2019
# 3    Elecciones Provinciales 12 de Mayo de 2019
# 4    Elecciones Provinciales 12 de Mayo de 2019
# ..                                          ...
# 708  Elecciones Provinciales 12 de Mayo de 2019
# 709  Elecciones Provinciales 12 de Mayo de 2019
# ...
