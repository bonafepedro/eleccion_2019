# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("resultados_electorales/resultados_circuitos.xlsx")
df['codigo_circuito1'] = df.codigo_circuito.str.zfill(5)

# %%
df['codigo_circuito'] = str(df['codigo_circuito'])

# %%
df
# Out:
#        ...1                                titulo
# 0        16  TRIBUNAL ELECTORAL PROVINCIAL AD HOC  \
# 1        17  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 2        18  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 3        19  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 4        20  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# ...     ...                                   ...
# 6331  30164  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 6332  30165  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 6333  30166  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 6334  30167  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
# 6335  30168  TRIBUNAL ELECTORAL PROVINCIAL AD HOC
#
#                                         eleccion                     circuito
# 0     Elecciones Provinciales 12 de Mayo de 2019  Circuito 53A   - LOS LEONES  \
# 1     Elecciones Provinciales 12 de Mayo de 2019  Circuito 53A   - LOS LEONES
# 2     Elecciones Provinciales 12 de Mayo de 2019  Circuito 53A   - LOS LEONES
# ...
